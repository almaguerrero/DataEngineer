# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Table of Content
#
# - **Introduction**
# - **Importing Libraries**
# - **Creating Function**
#     - Confusion Matrix plot
#     - Feature importance plot
#     - ROC curve plot
#     - Minimum PCA
#     - FPR and TPR
# - **Exploratory Data Analysis**
#     - Reading Data
#     - Exploring Data
#         -Target Column
#         -Features Selection
#     - Cleaning
#         - Missing Values
#         - Formatting Numerical Data
#         - Creating dummy variables for Categorical
# - **Modeling**
#     - Selecting performance metrics
#     - SMOT for class imbalance
#     - Logistic Regression
#     - SVM with PCA
#     - Random Forest
# - **Conclusion**
# - **Next Steps**

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import plotly.figure_factory as ff
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### - Reading the Data

# %%
data = pd.read_csv('data.csv')

print(data.shape)
data.head()
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (19,21,23,25,28,38,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (910993, 49)
#    IIDLOAN_A  SELENELNID  LMSID_A     LOANID   DEAL ORIG_DEAL DEALTYPE  \
# 0       9705         0.0        0        0.0     XX        XX       XX
# 1       1460      1008.0   317142  1559158.0  BOA01     BOA01     Loan
# 2       1460      1008.0   317142  1559158.0  BOA01     BOA01     Loan
# 3       1460      1008.0   317142  1559158.0  BOA01     BOA01     Loan
# 4       1460      1008.0   317142  1559158.0  BOA01     BOA01     Loan
#
#   PROPTYPE_M PROPTYPE_J LNSTATUS  ...       CTRTY         CTRANTYPE  \
# 0         XX         XX       XX  ...  EXP_DUEDIL        EXP_DUEDIL
# 1    SINGFAM    SINGFAM  PAIDOFF  ...    ACQ_INIT  Loan Acquisition
# ...

# %%
data.columns
# Out:
# Index(['IIDLOAN_A', 'SELENELNID', 'LMSID_A', 'LOANID', 'DEAL', 'ORIG_DEAL',
#        'DEALTYPE', 'PROPTYPE_M', 'PROPTYPE_J', 'LNSTATUS', 'STATE', 'LIQTYPE',
#        'LIQTYPE_JB', 'LIQ_DT', 'REALIZED', 'CURRENT_UP', 'ACQUIRED_U',
#        'AQUIS_DT', 'PURCH_PX', 'ADJ1_DT', 'ADJ1_TO_PX', 'ADJ2_DT',
#        'ADJ2_TO_PX', 'ADJ3_DT', 'ADJ3_TO_PX', 'ADJ4_DT', 'ADJ4_TO_PX',
#        'NET_PX', 'REO_FLAG', 'CURRENT_ST', 'CRULEBROKE', 'IIDTRAN',
#        'IIDLOAN_B', 'SELENELNI2', 'LMSID_B', 'NTRAN', 'NTRAN_OLD', 'DTRAN',
#        'DTRAN_OLD', 'CTRTY', 'CTRANTYPE', 'CTRTY_OLD', 'DVALUATION',
#        'CFILESRC', 'CFIELDSRC', 'CNOTES', 'NCHECKSUMN', 'NCHECKSUMD',
#        'NCHECKSUMC'],
#       dtype='object')

# %% [markdown]
# ### - Data Exploration

# %%
data.describe()
# Out:
#            IIDLOAN_A    SELENELNID       LMSID_A        LOANID  CURRENT_UP  \
# count  910993.000000  9.109930e+05  9.109930e+05  9.109930e+05    910993.0
# mean     4703.640529  6.299797e+06  6.901218e+05  1.119755e+09         0.0
# std      2860.820789  1.545788e+09  1.316378e+07  5.358682e+09         0.0
# min         1.000000  0.000000e+00  0.000000e+00  0.000000e+00         0.0
# 25%      2133.000000  3.224300e+04  5.311030e+05  1.735652e+06         0.0
# 50%      4436.000000  5.634100e+04  5.756140e+05  7.902370e+07         0.0
# 75%      7289.000000  7.913700e+04  6.128640e+05  7.715459e+08         0.0
# max      9705.000000  8.438650e+11  1.111111e+09  8.438650e+11         0.0
#
#          ACQUIRED_U      PURCH_PX     ADJ1_TO_PX     ADJ2_TO_PX  \
# count  9.109930e+05  9.109930e+05  910993.000000  910993.000000
# mean   2.215470e+05  1.049675e+05     301.536291    -591.879155
# std    1.963156e+05  1.207395e+05    5978.210229    7318.465744
# ...

# %%
dt_1=data["LMSID_A"]
dt_2=data["DEAL"]
dt_3=data["DEALTYPE"]
dt_4=data["PROPTYPE_M"]
dt_5=data["PROPTYPE_J"]
dt_6=data["STATE"]
dt_7=data["LIQTYPE_JB"]
dt_8=data["LIQ_DT"]
dt_9=data["NTRAN"]
dt_10=data["DTRAN"]

df = pd.concat([dt_1,dt_2,dt_3,dt_4,dt_5,dt_6,dt_7,dt_8,dt_10,dt_9], axis=1)
df['DTRAN'] = pd.to_datetime(df["DTRAN"]).dt.strftime('%Y-%m-%d')

# %%
plt.figure(figsize=(10,10))  ##tamaño de la figura 
sns.lineplot(x=df['DTRAN'], y=df['NTRAN'])

# %%
plt.figure(figsize=(10,5))
chart = sns.stripplot(x=data['STATE'],y=data['NTRAN'],palette='rainbow')
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'XX'),
#  Text(0, 0, 'IL'),
#  Text(0, 0, 'CA'),
#  Text(0, 0, 'MN'),
#  Text(0, 0, 'NC'),
#  Text(0, 0, 'WA'),
#  Text(0, 0, 'AZ'),
#  Text(0, 0, 'NJ'),
#  Text(0, 0, 'CO'),
#  Text(0, 0, 'MI'),
#  Text(0, 0, 'TX'),
#  Text(0, 0, 'ME'),
#  Text(0, 0, 'GA'),
#  Text(0, 0, 'MA'),
#  Text(0, 0, 'VA'),
#  Text(0, 0, 'RI'),
#  Text(0, 0, 'LA'),
#  Text(0, 0, 'MD'),
#  Text(0, 0, 'NY'),
#  Text(0, 0, 'AL'),
#  Text(0, 0, 'FL'),
#  Text(0, 0, 'PA'),
#  Text(0, 0, 'OR'),
#  Text(0, 0, 'WI'),
#  Text(0, 0, 'TN'),
#  Text(0, 0, 'NM'),
#  Text(0, 0, 'UT'),
#  Text(0, 0, 'OK'),
#  Text(0, 0, 'KY'),
#  Text(0, 0, 'NV'),
#  Text(0, 0, 'CT'),
#  Text(0, 0, 'NE'),
#  Text(0, 0, 'MS'),
#  Text(0, 0, 'SC'),
#  Text(0, 0, 'IN'),
#  Text(0, 0, 'OH'),
#  Text(0, 0, 'IA'),
#  Text(0, 0, 'ND'),
#  Text(0, 0, 'MO'),
#  Text(0, 0, 'DE'),
#  Text(0, 0, 'ID'),
#  Text(0, 0, 'KS'),
#  Text(0, 0, 'MT'),
#  Text(0, 0, 'HI'),
#  Text(0, 0, 'WV'),
#  Text(0, 0, 'DC'),
#  Text(0, 0, 'NH'),
# ...

# %%
plt.figure(figsize=(10,5))
chart = sns.stripplot(x=data['PROPTYPE_M'],y=data['NTRAN'],palette='rainbow')
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'XX'),
#  Text(0, 0, 'SINGFAM'),
#  Text(0, 0, 'PUD'),
#  Text(0, 0, '2FAM'),
#  Text(0, 0, 'CONDO'),
#  Text(0, 0, 'TOWNHOUSE'),
#  Text(0, 0, 'ROWHOUSE'),
#  Text(0, 0, 'VACANTLAND'),
#  Text(0, 0, '4FAM'),
#  Text(0, 0, '3FAM'),
#  Text(0, 0, 'MH'),
#  Text(0, 0, 'DUPLEX'),
#  Text(0, 0, 'MIXEDUSE'),
#  Text(0, 0, 'FARMORRANCH'),
#  Text(0, 0, 'COMMERCIAL'),
#  Text(0, 0, 'PendingBroke')]
